# %% [markdown]
# # Evaluación del modelo

# %% [markdown]
# ## Decision Transformer

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import DataLoader
import pickle
import os
import json

from src.data.load_data import load_training_data
from src.data.preprocessing import create_dt_dataset, validate_preprocessing
from src.data.dataset import RecommendationDataset
from src.models.decision_transformer import DecisionTransformer
from src.training.trainer import train_decision_transformer
from src.evaluation.evaluate import evaluate_model


# === CONFIGURACIÓN DEL DATASET ===
# Cambiar aquí para elegir Netflix o Goodreads
DATASET = 'netflix'  # o 'goodreads'

if DATASET == 'netflix':
    NUM_ITEMS = 752
    train_path = 'data/train/netflix8_train.df'
    test_path = 'data/test_users/netflix8_test.json'
else:
    NUM_ITEMS = 472
    train_path = 'data/train/goodreads8_train.df'
    test_path = 'data/test_users/goodreads8_test.json'

NUM_GROUPS = 8

# %%
# Cargar datos de entrenamiento
from src.data.load_data import load_training_data

df_train = pd.read_pickle(train_path)

# %%
# Crear dataset
from src.data.preprocessing import create_dt_dataset, validate_preprocessing

trajectories = create_dt_dataset(df_train)
validate_preprocessing(trajectories)

# %%
from src.data.dataset import RecommendationDataset
from torch.utils.data import DataLoader

dataset = RecommendationDataset(trajectories, context_length=20)
loader = DataLoader(dataset, batch_size=64, shuffle=True)

# Verificar un batch
batch = next(iter(loader))
print(f"Keys: {batch.keys()}")
print(f"States shape: {batch['states'].shape}")  # (64, 20)
# Out:
# Keys: dict_keys(['states', 'actions', 'rtg', 'timesteps', 'groups', 'targets'])
# States shape: torch.Size([64, 20])

# %%
# Creamos un modelo
from src.models.decision_transformer import DecisionTransformer

model = DecisionTransformer(
    num_items=752,
    num_groups=8,
    hidden_dim=128,
    n_layers=3,
    n_heads=4
)

print(f"Parámetros totales: {sum(p.numel() for p in model.parameters())}")
# Debería ser ~10-20M parámetros
# Out:
# Parámetros totales: 831728

# %%
# Entrnamiento básico
from src.training.trainer import train_decision_transformer

# Configuración del dispositivo
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

train, history = train_decision_transformer(
    model=model,
    train_loader=loader,
    optimizer=torch.optim.Adam(model.parameters(), lr=1e-4),
    device=device,
    num_epochs=50
)
# Out:
# Using device: cuda
# Epoch 1/50:
#   Train Loss: 6.6240
# Epoch 2/50:
#   Train Loss: 6.6239
# Epoch 3/50:
#   Train Loss: 6.6236
# Epoch 4/50:
#   Train Loss: 6.6236
# Epoch 5/50:
#   Train Loss: 6.6236
# Epoch 6/50:
#   Train Loss: 6.6234
# Epoch 7/50:
#   Train Loss: 6.6234
# Epoch 8/50:
#   Train Loss: 6.6234
# Epoch 9/50:
#   Train Loss: 6.6233
# Epoch 10/50:
#   Train Loss: 6.6233
# Epoch 11/50:
#   Train Loss: 6.6232
# Epoch 12/50:
#   Train Loss: 6.6231
# Epoch 13/50:
#   Train Loss: 6.6231
# Epoch 14/50:
#   Train Loss: 6.6232
# Epoch 15/50:
#   Train Loss: 6.6230
# Epoch 16/50:
#   Train Loss: 6.6231
# Epoch 17/50:
#   Train Loss: 6.6230
# Epoch 18/50:
#   Train Loss: 6.6228
# Epoch 19/50:
#   Train Loss: 6.6228
# Epoch 20/50:
#   Train Loss: 6.6229
# Epoch 21/50:
#   Train Loss: 6.6228
# Epoch 22/50:
#   Train Loss: 6.6228
# Epoch 23/50:
#   Train Loss: 6.6227
# Epoch 24/50:
#   Train Loss: 6.6228
# Epoch 25/50:
#   Train Loss: 6.6227
# Epoch 26/50:
#   Train Loss: 6.6228
# Epoch 27/50:
#   Train Loss: 6.6227
# Epoch 28/50:
#   Train Loss: 6.6227
# Epoch 29/50:
#   Train Loss: 6.6226
# Epoch 30/50:
#   Train Loss: 6.6226
# Epoch 31/50:
#   Train Loss: 6.6226
# Epoch 32/50:
#   Train Loss: 6.6226
# Epoch 33/50:
#   Train Loss: 6.6226
# Epoch 34/50:
#   Train Loss: 6.6226
# Epoch 35/50:
#   Train Loss: 6.6226
# Epoch 36/50:
#   Train Loss: 6.6226
# Epoch 37/50:
#   Train Loss: 6.6226
# Epoch 38/50:
#   Train Loss: 6.6226
# Epoch 39/50:
#   Train Loss: 6.6226
# Epoch 40/50:
#   Train Loss: 6.6225
# Epoch 41/50:
#   Train Loss: 6.6226
# Epoch 42/50:
#   Train Loss: 6.6225
# Epoch 43/50:
#   Train Loss: 6.6225
# Epoch 44/50:
#   Train Loss: 6.6225
# Epoch 45/50:
#   Train Loss: 6.6225
# Epoch 46/50:
#   Train Loss: 6.6225
# Epoch 47/50:
#   Train Loss: 6.6225
# Epoch 48/50:
#   Train Loss: 6.6225
# Epoch 49/50:
#   Train Loss: 6.6225
# Epoch 50/50:
#   Train Loss: 6.6225

# %%
# Evaluación del modelo
from src.evaluation.evaluate import evaluate_model

print("\nEvaluando en cold-start...")

with open(test_path, 'r') as f:
    test_data = json.load(f)

print(f"Test users: {len(test_data)}")

results_dt = evaluate_model(
    model=model,
    test_data=test_data,
    device=device,
    target_return=None,  # usar máximo posible
    k_list=[5, 10, 20]
)

print("\n" + "="*60)
print("RESULTADOS FINALES")
print("="*60)
for metric, value in results_dt.items():
    print(f"{metric:12s}: {value:.4f}")
print("="*60)

# %% [markdown]
# ## Popularity Recommender

# %%
from src.models.baselines import PopularityRecommender

popularity = PopularityRecommender()
popularity.fit(trajectories)

rec = popularity.recommend(user_history=[10, 20, 30], k=10)
print(f"Recomendaciones basadas en popularidad: {rec}")
# Out:
# Recomendaciones basadas en popularidad: [np.int64(505), np.int64(579), np.int64(420), np.int64(532), np.int64(589), np.int64(63), np.int64(13), np.int64(622), np.int64(358), np.int64(213)]

# %%
print("\nEvaluando en cold-start...")

with open(test_path, 'r') as f:
    test_data = json.load(f)

print(f"Test users: {len(test_data)}")
# Out:
# Evaluando en cold-start...
# Test users: 1600

# %%
from src.evaluation.evaluate import evaluate_popularity_baseline

results_pop = evaluate_popularity_baseline(popularity, test_data, k_list=[5, 10, 20])

# %%
#Mostrar resultados
print("📊 Resultados PopularityRecommender:")
print("="*50)
for metric, value in results_pop.items():
    print(f"{metric}: {value:.4f}")
# Out:
# 📊 Resultados PopularityRecommender:
# ==================================================
# HR@5: 0.0383
# HR@10: 0.0697
# HR@20: 0.1257
# NDCG@5: 0.0256
# NDCG@10: 0.0355
# NDCG@20: 0.0495
# MRR: 0.0291
